# %%
import matplotlib.pyplot as plt

# %%
# Temps séquentiels
# temps_seq_AF = 4  # sec
# temps_seq_AM = 54  # sec
# temps_seq_AN = 739  # sec 
temps_seq_AF = 7  # sec
temps_seq_AM = 113.6  # sec
temps_seq_AN = 1774  # sec

# Valeurs pour l'axe des abscisses
x_values_F = list(range(2, 21, 2))  # Pour AF
x_values_M = list(range(5, 51, 5))  # Pour AM
x_values_N = list(range(10, 101, 10))  # Pour AN

# Données pour chaque ensemble
data_AF = [4.14709, 2.60108, 1.92217, 1.76517, 1.6718, 1.75196, 1.81537, 1.60957, 2.00143, 1.97625]
data_AM = [27.7337, 17.5035, 13.895, 12.9439, 11.9752, 10.2072, 10.9645, 11.5218, 11.2107, 11.631]
data_AN = [249.091, 144.163, 110.069, 83.6744, 83.9393, 63.0742, 64.7037, 68.1358, 70.1598, 69.086]

# Calcul de l'accélération
acceleration_AF = [temps_seq_AF / t for t in data_AF]
acceleration_AM = [temps_seq_AM / t for t in data_AM]
acceleration_AN = [temps_seq_AN / t for t in data_AN]

# Calcul de l'efficacité
efficacite_AF = [a / p for a, p in zip(acceleration_AF, x_values_F)]
efficacite_AM = [a / p for a, p in zip(acceleration_AM, x_values_M)]
efficacite_AN = [a / p for a, p in zip(acceleration_AN, x_values_N)]

# %%
import matplotlib.pyplot as plt
# Temps séquentiels
# temps_seq_AF = 4  # sec
# temps_seq_AM = 54  # sec
# temps_seq_AN = 739  # sec 
temps_seq_AF = 7  # sec
temps_seq_AM = 113.6  # sec
temps_seq_AN = 1774  # sec

# Valeurs pour l'axe des abscisses
x_values_F = list(range(2, 21, 2))  # Pour AF
x_values_M = list(range(5, 51, 5))  # Pour AM
x_values_N = list(range(10, 101, 10))  # Pour AN

# Données pour chaque ensemble
data_AF = [4.14709, 2.60108, 1.92217, 1.76517, 1.6718, 1.75196, 1.81537, 1.60957, 2.00143, 1.97625]
data_AM = [27.7337, 17.5035, 13.895, 12.9439, 11.9752, 10.2072, 10.9645, 11.5218, 11.2107, 11.631]
data_AN = [249.091, 144.163, 110.069, 83.6744, 83.9393, 63.0742, 64.7037, 68.1358, 70.1598, 69.086]

# Calcul de l'accélération
acceleration_AF = [temps_seq_AF / t for t in data_AF]
acceleration_AM = [temps_seq_AM / t for t in data_AM]
acceleration_AN = [temps_seq_AN / t for t in data_AN]

# Calcul de l'efficacité
efficacite_AF = [a / p for a, p in zip(acceleration_AF, x_values_F)]
efficacite_AM = [a / p for a, p in zip(acceleration_AM, x_values_M)]
efficacite_AN = [a / p for a, p in zip(acceleration_AN, x_values_N)]

# Création des graphiques
plt.figure(figsize=(18, 6))

# Graphique pour AF
ax1 = plt.subplot(1, 3, 1)
ax1.plot(x_values_F, data_AF, marker='o', color='blue', label='Temps AF')
ax1.set_xlabel('Nombre de Processus')
ax1.set_ylabel('Temps (sec)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.grid(True)

ax2 = ax1.twinx()
ax2.plot(x_values_F, acceleration_AF, marker='x', color='green', label='Accélération AF')
ax2.set_ylabel('Accélération', color='green')
ax2.tick_params(axis='y', labelcolor='green')

ax1.set_title('AF - Temps, Accélération')

# Graphique pour AM
ax1 = plt.subplot(1, 3, 2)
ax1.plot(x_values_M, data_AM, marker='o', color='blue', label='Temps AM')
ax1.set_xlabel('Nombre de Processus')
ax1.set_ylabel('Temps (sec)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.grid(True)

ax2 = ax1.twinx()
ax2.plot(x_values_M, acceleration_AM, marker='x', color='green', label='Accélération AM')
ax2.set_ylabel('Accélération', color='green')
ax2.tick_params(axis='y', labelcolor='green')

ax1.set_title('AM - Temps, Accélération')

# Graphique pour AN
ax1 = plt.subplot(1, 3, 3)
ax1.plot(x_values_N, data_AN, marker='o', color='blue', label='Temps AN')
ax1.set_xlabel('Nombre de Processus')
ax1.set_ylabel('Temps (sec)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.grid(True)

ax2 = ax1.twinx()
ax2.plot(x_values_N, acceleration_AN, marker='x', color='green', label='Accélération AN')
ax2.set_ylabel('Accélération', color='green')
ax2.tick_params(axis='y', labelcolor='green')

ax1.set_title('AN - Temps, Accélération ')

plt.tight_layout()
plt.show()

# %%
# Création des graphiques
plt.figure(figsize=(18, 6))

# Comparaison de l'efficacité
plt.subplot(1, 3, 1)
plt.plot(x_values_F, efficacite_AF, marker='o', color='blue', linestyle='-', label='Efficacité AF')
plt.plot(x_values_M, efficacite_AM, marker='o', color='red', linestyle='-', label='Efficacité AM')
plt.plot(x_values_N, efficacite_AN, marker='o', color='green', linestyle='-', label='Efficacité AN')
plt.title('Comparaison de l\'Efficacité')
plt.xlabel('Nombre de Processus')
plt.ylabel('Efficacité')
plt.legend()
plt.grid(True)

# Comparaison de l'accélération
plt.subplot(1, 3, 2)
plt.plot(x_values_F, acceleration_AF, marker='x', color='blue', linestyle='-', label='Accélération AF')
plt.plot(x_values_M, acceleration_AM, marker='x', color='red', linestyle='-', label='Accélération AM')
plt.plot(x_values_N, acceleration_AN, marker='x', color='green', linestyle='-', label='Accélération AN')
plt.title('Comparaison de l\'Accélération')
plt.xlabel('Nombre de Processus')
plt.ylabel('Accélération')
plt.legend()
plt.grid(True)

# Comparaison des temps
plt.subplot(1, 3, 3)
plt.plot(x_values_F, data_AF, marker='^', color='blue', linestyle='-', label='Temps AF')
plt.plot(x_values_M, data_AM, marker='^', color='red', linestyle='-', label='Temps AM')
plt.plot(x_values_N, data_AN, marker='^', color='green', linestyle='-', label='Temps AN')
plt.title('Comparaison des Temps')
plt.xlabel('Nombre de Processus')
plt.ylabel('Temps (sec)')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Temps séquentiels mis à jour
temps_seq_AF = 7  # sec
temps_seq_AM = 113.6  # sec
temps_seq_AN = 1774  # sec

# Données de temps pour chaque configuration
data_AF = [4.31391, 2.78042, 2.30198, 2.10074, 2.02537, 2.12954, 2.02209, 2.19334, 2.31418, 3.29918]
data_AM = [46.4581, 26.8616, 21.1436, 18.2939, 16.1195, 15.389, 13.815, 14.3698, 14.333, 17.0404]
data_AN = [258.38, 156.059, 118.145, 91.2676, 86.6637, 76.1918, 69.7505, 65.0219, 63.2936, 60.5209, 62.4865, 61.2595, 58.4058, 61.8252, 65.3665]

# Valeurs pour l'axe des abscisses
x_values_F = list(range(2, 21, 2))  # Pour AF
x_values_M = list(range(3, 31, 3))  # Pour AM
x_values_N = list(range(10, 151, 10))  # Pour AN

# Calcul de l'accélération
acceleration_AF = [temps_seq_AF / t for t in data_AF]
acceleration_AM = [temps_seq_AM / t for t in data_AM]
acceleration_AN = [temps_seq_AN / t for t in data_AN]

# Calcul de l'efficacité
efficacite_AF = [a / p for a, p in zip(acceleration_AF, x_values_F)]
efficacite_AM = [a / p for a, p in zip(acceleration_AM, x_values_M)]
efficacite_AN = [a / p for a, p in zip(acceleration_AN, x_values_N)]

# %%
# Création des graphiques
plt.figure(figsize=(18, 6))

# Graphique pour AF
ax1 = plt.subplot(1, 3, 1)
ax1.plot(x_values_F, data_AF, marker='o', color='blue', label='Temps AF')
ax1.set_xlabel('Nombre de Processus')
ax1.set_ylabel('Temps (sec)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.grid(True)

ax2 = ax1.twinx()
ax2.plot(x_values_F, acceleration_AF, marker='x', color='green', label='Accélération AF')
ax2.set_ylabel('Accélération', color='green')
ax2.tick_params(axis='y', labelcolor='green')

ax1.set_title('AF - Temps et Accélération')

# Graphique pour AM
ax1 = plt.subplot(1, 3, 2)
ax1.plot(x_values_M, data_AM, marker='o', color='blue', label='Temps AM')
ax1.set_xlabel('Nombre de Processus')
ax1.set_ylabel('Temps (sec)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.grid(True)

ax2 = ax1.twinx()
ax2.plot(x_values_M, acceleration_AM, marker='x', color='green', label='Accélération AM')
ax2.set_ylabel('Accélération', color='green')
ax2.tick_params(axis='y', labelcolor='green')

ax1.set_title('AM - Temps et Accélération')

# Graphique pour AN
ax1 = plt.subplot(1, 3, 3)
ax1.plot(x_values_N, data_AN, marker='o', color='blue', label='Temps AN')
ax1.set_xlabel('Nombre de Processus')
ax1.set_ylabel('Temps (sec)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.grid(True)

ax2 = ax1.twinx()
ax2.plot(x_values_N, acceleration_AN, marker='x', color='green', label='Accélération AN')
ax2.set_ylabel('Accélération', color='green')
ax2.tick_params(axis='y', labelcolor='green')

ax1.set_title('AN - Temps et Accélération')

plt.tight_layout()
plt.show()

# %%
# Création des graphiques
plt.figure(figsize=(18, 6))

# Comparaison de l'efficacité
plt.subplot(1, 3, 1)
plt.plot(x_values_F, efficacite_AF, marker='o', color='blue', linestyle='-', label='Efficacité AF')
plt.plot(x_values_M, efficacite_AM, marker='o', color='red', linestyle='-', label='Efficacité AM')
plt.plot(x_values_N, efficacite_AN, marker='o', color='green', linestyle='-', label='Efficacité AN')
plt.title('Comparaison de l\'Efficacité')
plt.xlabel('Nombre de Processus')
plt.ylabel('Efficacité')
plt.legend()
plt.grid(True)

# Comparaison de l'accélération
plt.subplot(1, 3, 2)
plt.plot(x_values_F, acceleration_AF, marker='x', color='blue', linestyle='-', label='Accélération AF')
plt.plot(x_values_M, acceleration_AM, marker='x', color='red', linestyle='-', label='Accélération AM')
plt.plot(x_values_N, acceleration_AN, marker='x', color='green', linestyle='-', label='Accélération AN')
plt.title('Comparaison de l\'Accélération')
plt.xlabel('Nombre de Processus')
plt.ylabel('Accélération')
plt.legend()
plt.grid(True)

# Comparaison des temps
plt.subplot(1, 3, 3)
plt.plot(x_values_F, data_AF, marker='^', color='blue', linestyle='-', label='Temps AF')
plt.plot(x_values_M, data_AM, marker='^', color='red', linestyle='-', label='Temps AM')
plt.plot(x_values_N, data_AN, marker='^', color='green', linestyle='-', label='Temps AN')
plt.title('Comparaison des Temps')
plt.xlabel('Nombre de Processus')
plt.ylabel('Temps (sec)')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
